# %%
import numpy as np
import pandas as pd
import scipy as sp

# %% [markdown]
# # Data preprocessing

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # Regression Models

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor

# %% [markdown]
# # Packages for model selection

# %%
from sklearn.model_selection import cross_validate, cross_val_score, RepeatedKFold
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

# %% [markdown]
# # To ignore warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model Deployment

# %%
import pickle

# %%
data=pd.read_csv('SecondCar.csv')
print(data.head(2))
data.shape
# Out:
#                              name  year  km_driven    fuel seller_type  \
# 0  Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1               Tata Nano Lx BSIV  2012      50000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000
# (4340, 10)

# %% [markdown]
# # Solution

# %%
data.iloc[0]
# Out:
# name                Tata Indica Vista Aqua 1.4 TDI
# year                                          2010
# km_driven                                   120000
# fuel                                        Diesel
# seller_type                             Individual
# transmission                                Manual
# owner                                 Second Owner
# Rating                                         9.0
# ExShowroom Price                            106001
# selling_price                               100000
# Name: 0, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              4340 non-null   object
#  1   year              4340 non-null   int64
#  2   km_driven         4340 non-null   int64
#  3   fuel              4337 non-null   object
#  4   seller_type       4338 non-null   object
#  5   transmission      4338 non-null   object
#  6   owner             4337 non-null   object
#  7   Rating            4336 non-null   float64
#  8   ExShowroom Price  4340 non-null   int64
#  9   selling_price     4340 non-null   int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 339.2+ KB

# %%
data.iloc[[0,1,2],[2,3,4]]
# Out:
#    km_driven    fuel seller_type
# 0     120000  Diesel  Individual
# 1      50000  Petrol  Individual
# 2      70000  Diesel  Individual

# %%
data.mode()
# Out:
#                      name    year  km_driven    fuel seller_type transmission  \
# 0  Maruti Swift Dzire VDI  2017.0    70000.0  Diesel  Individual       Manual
# 1                     NaN     NaN        NaN     NaN         NaN          NaN
# 2                     NaN     NaN        NaN     NaN         NaN          NaN
# 3                     NaN     NaN        NaN     NaN         NaN          NaN
# 4                     NaN     NaN        NaN     NaN         NaN          NaN
# 5                     NaN     NaN        NaN     NaN         NaN          NaN
# 6                     NaN     NaN        NaN     NaN         NaN          NaN
# 7                     NaN     NaN        NaN     NaN         NaN          NaN
# 8                     NaN     NaN        NaN     NaN         NaN          NaN
#
#          owner  Rating  ExShowroom Price  selling_price
# 0  First Owner     9.0            318101       300000.0
# 1          NaN     NaN            447196            NaN
# 2          NaN     NaN            480502            NaN
# 3          NaN     NaN            490675            NaN
# 4          NaN     NaN            517119            NaN
# 5          NaN     NaN            522530            NaN
# 6          NaN     NaN            553068            NaN
# 7          NaN     NaN            574696            NaN
# 8          NaN     NaN           1003871            NaN

# %% [markdown]
# # Replacing Null Values Or NA Data With Median, Mode Values Of Data In Respective Columns

# %%
for col in data.columns:
    if data[col].dtype == 'int32' or data[col].dtype == 'int64' or data[col].dtype == 'float32' or data[col].dtype == 'float64':
        median = data[col].median()
        data[col].fillna(data[col].median(), inplace= True)
        
    else:
        #print('Hello') 
        #input()
        data = data.fillna(data.mode().iloc[0])
        #print(col,end=" ")
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price
# 0            100000
# 1            100000
# 2            120000
# 3            100000
# 4            130000
# ...             ...
# 4335        4950000
# 4336        4800000
# 4337        4950000
# 4338        8900000
# 4339        8150000
#
# [4340 rows x 10 columns]

# %%
data.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data.median()
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11706, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11698 @doc(make_doc("median", ndim=2))
#   11699 def median(
#   11700     self,
#    (...)
#   11704     **kwargs,
#   11705 ):
# > 11706     result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707     if isinstance(result, Series):
#   11708         result = result.__finalize__(self, method="median")
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# > 12431     return self._stat_function(
#   12432         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433     )
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
#   11563 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11481, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11479         return np.array([result])
#   11480 else:
# > 11481     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\Kasim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     785     inferred = lib.infer_dtype(values)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#     789     values = values.astype("f8")
#
# TypeError: Cannot convert [['Second Owner' 'Second Owner' 'First Owner' ... 'First Owner'
#   'First Owner' 'First Owner']] to numeric

# %%
data.isna().sum() #API
# Out:
# name                0
# year                0
# km_driven           0
# fuel                0
# seller_type         0
# transmission        0
# owner               0
# Rating              0
# ExShowroom Price    0
# selling_price       0
# dtype: int64

# %%
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price
# 0            100000
# 1            100000
# 2            120000
# 3            100000
# 4            130000
# ...             ...
# 4335        4950000
# 4336        4800000
# 4337        4950000
# 4338        8900000
# 4339        8150000
#
# [4340 rows x 10 columns]

# %%
data[data.isnull().any(axis=1)==True]
# Out:
# Empty DataFrame
# Columns: [name, year, km_driven, fuel, seller_type, transmission, owner, Rating, ExShowroom Price, selling_price]
# Index: []

# %% [markdown]
# # Unique Value Check for categorial columns

# %%
data.nunique()
# Out:
# name                1491
# year                  27
# km_driven            770
# fuel                   5
# seller_type            3
# transmission           2
# owner                  5
# Rating               566
# ExShowroom Price    4331
# selling_price        445
# dtype: int64

# %%
len(data)
# Out:
# 4340

# %%
len(data.columns[0])
# Out:
# 4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              4340 non-null   object
#  1   year              4340 non-null   int64
#  2   km_driven         4340 non-null   int64
#  3   fuel              4340 non-null   object
#  4   seller_type       4340 non-null   object
#  5   transmission      4340 non-null   object
#  6   owner             4340 non-null   object
#  7   Rating            4340 non-null   float64
#  8   ExShowroom Price  4340 non-null   int64
#  9   selling_price     4340 non-null   int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 339.2+ KB

# %%
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price
# 0            100000
# 1            100000
# 2            120000
# 3            100000
# 4            130000
# ...             ...
# 4335        4950000
# 4336        4800000
# 4337        4950000
# 4338        8900000
# 4339        8150000
#
# [4340 rows x 10 columns]

# %% [markdown]
# # Feature Engineering

# %%
data['company_name']=data['name'].str.split(' ').str[0]
data.head()
# Out:
#                                name  year  km_driven    fuel seller_type  \
# 0    Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1                 Tata Nano Lx BSIV  2012      50000  Petrol  Individual
# 2  Tata Indica Vista Aqua TDI BSIII  2011      70000  Diesel  Individual
# 3          Maruti Wagon R LXI Minor  2010      80000  Petrol  Individual
# 4                 Chevrolet Beat LT  2010      80000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price  \
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000
# 2       Manual   First Owner    11.0            120678         120000
# 3       Manual  Second Owner     9.0            122917         100000
# 4       Manual  Second Owner    10.0            144902         130000
#
#   company_name
# 0         Tata
# 1         Tata
# 2         Tata
# 3       Maruti
# 4    Chevrolet

# %%
data['name'].str.split(' ').str[1]
# Out:
# 0        Indica
# 1          Nano
# 2        Indica
# 3         Wagon
# 4          Beat
#          ...
# 4335         X5
# 4336          5
# 4337         X5
# 4338        RS7
# 4339    S-Class
# Name: name, Length: 4340, dtype: object

# %%
data.company_name.unique()
# Out:
# array(['Tata', 'Maruti', 'Chevrolet', 'Hyundai', 'Ford', 'Volkswagen',
#        'Mahindra', 'Fiat', 'Nissan', 'Renault', 'Toyota', 'Datsun',
#        'Honda', 'Skoda', 'Ambassador', 'OpelCorsa', 'Daewoo', 'Force',
#        'Mercedes-Benz', 'BMW', 'Audi', 'Mitsubishi', 'Jeep', 'Isuzu',
#        'Kia', 'Volvo', 'Jaguar', 'MG', 'Land'], dtype=object)

# %%
data.company_name.nunique()
# Out:
# 29

# %%
data.company_name.unique()
# Out:
# array(['Tata', 'Maruti', 'Chevrolet', 'Hyundai', 'Ford', 'Volkswagen',
#        'Mahindra', 'Fiat', 'Nissan', 'Renault', 'Toyota', 'Datsun',
#        'Honda', 'Skoda', 'Ambassador', 'OpelCorsa', 'Daewoo', 'Force',
#        'Mercedes-Benz', 'BMW', 'Audi', 'Mitsubishi', 'Jeep', 'Isuzu',
#        'Kia', 'Volvo', 'Jaguar', 'MG', 'Land'], dtype=object)

# %% [markdown]
# # Feature enginering for kilometers

# %%
km_ranges=['low','medium','high']
limits=[0,35000,100000,2000000]
data['km_range']=pd.cut(data['km_driven'],bins=limits,labels=km_ranges)

data.head(5)
# Out:
#                                name  year  km_driven    fuel seller_type  \
# 0    Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1                 Tata Nano Lx BSIV  2012      50000  Petrol  Individual
# 2  Tata Indica Vista Aqua TDI BSIII  2011      70000  Diesel  Individual
# 3          Maruti Wagon R LXI Minor  2010      80000  Petrol  Individual
# 4                 Chevrolet Beat LT  2010      80000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price  \
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000
# 2       Manual   First Owner    11.0            120678         120000
# 3       Manual  Second Owner     9.0            122917         100000
# 4       Manual  Second Owner    10.0            144902         130000
#
#   company_name km_range
# 0         Tata     high
# 1         Tata   medium
# 2         Tata   medium
# 3       Maruti   medium
# 4    Chevrolet   medium

# %%
round(data.describe(),0)
# Out:
#          year  km_driven  Rating  ExShowroom Price  selling_price
# count  4340.0     4340.0  4340.0            4340.0         4340.0
# mean   2013.0    66216.0    12.0          845381.0       504127.0
# std       4.0    46644.0     2.0          884841.0       578549.0
# min    1992.0        1.0     9.0          106001.0        20000.0
# 25%    2011.0    35000.0    10.0          445390.0       208750.0
# 50%    2014.0    60000.0    12.0          596055.0       350000.0
# 75%    2016.0    90000.0    14.0          946243.0       600000.0
# max    2020.0   806599.0    15.0        15538153.0      8900000.0

# %%
data.describe()
# Out:
#               year      km_driven       Rating  ExShowroom Price  \
# count  4340.000000    4340.000000  4340.000000      4.340000e+03
# mean   2013.090783   66215.777419    11.962984      8.453809e+05
# std       4.215344   46644.102194     1.912088      8.848405e+05
# min    1992.000000       1.000000     9.000000      1.060010e+05
# 25%    2011.000000   35000.000000    10.020000      4.453895e+05
# 50%    2014.000000   60000.000000    12.000000      5.960550e+05
# 75%    2016.000000   90000.000000    13.760000      9.462430e+05
# max    2020.000000  806599.000000    15.000000      1.553815e+07
#
#        selling_price
# count   4.340000e+03
# mean    5.041273e+05
# std     5.785487e+05
# min     2.000000e+04
# 25%     2.087498e+05
# 50%     3.500000e+05
# 75%     6.000000e+05
# max     8.900000e+06

# %% [markdown]
# # Features For Years

# %%
year_ranges=['Junk','Scrap','Buy','Best']
limits=[1991,2005,2010,2015,2020]
data['year_range']=pd.cut(data['year'],bins=limits,labels=year_ranges)

data.head(5)
# Out:
#                                name  year  km_driven    fuel seller_type  \
# 0    Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1                 Tata Nano Lx BSIV  2012      50000  Petrol  Individual
# 2  Tata Indica Vista Aqua TDI BSIII  2011      70000  Diesel  Individual
# 3          Maruti Wagon R LXI Minor  2010      80000  Petrol  Individual
# 4                 Chevrolet Beat LT  2010      80000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price  \
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000
# 2       Manual   First Owner    11.0            120678         120000
# 3       Manual  Second Owner     9.0            122917         100000
# 4       Manual  Second Owner    10.0            144902         130000
#
#   company_name km_range year_range
# 0         Tata     high      Scrap
# 1         Tata   medium        Buy
# 2         Tata   medium        Buy
# 3       Maruti   medium      Scrap
# 4    Chevrolet   medium      Scrap

# %% [markdown]
# # Feature for ex showroom price

# %%
ex_range=['Affordable','family','Luxury','Premium']
limits=[0,500000,1000000,1500000,20000000]
data['ex_range']=pd.cut(data['ExShowroom Price'],bins=limits,labels=ex_range)

data.head(5)
# Out:
#                                name  year  km_driven    fuel seller_type  \
# 0    Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1                 Tata Nano Lx BSIV  2012      50000  Petrol  Individual
# 2  Tata Indica Vista Aqua TDI BSIII  2011      70000  Diesel  Individual
# 3          Maruti Wagon R LXI Minor  2010      80000  Petrol  Individual
# 4                 Chevrolet Beat LT  2010      80000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price  \
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000
# 2       Manual   First Owner    11.0            120678         120000
# 3       Manual  Second Owner     9.0            122917         100000
# 4       Manual  Second Owner    10.0            144902         130000
#
#   company_name km_range year_range    ex_range
# 0         Tata     high      Scrap  Affordable
# 1         Tata   medium        Buy  Affordable
# 2         Tata   medium        Buy  Affordable
# 3       Maruti   medium      Scrap  Affordable
# 4    Chevrolet   medium      Scrap  Affordable

# %% [markdown]
# # Label Encoding

# %%
data['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
EN=LabelEncoder()
data['fuel']=EN.fit_transform(data['fuel'])

data['fuel'].unique()
# Out:
# array([1, 4, 0, 3, 2])

# %%
data['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['transmission']=EN.fit_transform(data['transmission'])
data['transmission'].unique()
# Out:
# array([1, 0])

# %%
data.seller_type.unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
data['name']=EN.fit_transform(data['name'])
data['seller_type']=EN.fit_transform(data['seller_type'])
data['owner']=EN.fit_transform(data['owner'])
data['company_name']=EN.fit_transform(data['company_name'])
data['km_range']=EN.fit_transform(data['km_range'])
data['year_range']=EN.fit_transform(data['year_range'])
data['ex_range']=EN.fit_transform(data['ex_range'])

data.head()
# Out:
#    name  year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# 0  1228  2010     120000     1            1             1      2     9.0
# 1  1283  2012      50000     4            1             1      2     9.0
# 2  1229  2011      70000     1            1             1      0    11.0
# 3  1041  2010      80000     4            1             1      2     9.0
# 4    56  2010      80000     4            1             1      2    10.0
#
#    ExShowroom Price  selling_price  company_name  km_range  year_range  \
# 0            106001         100000            25         0           3
# 1            108556         100000            25         2           1
# 2            120678         120000            25         2           1
# 3            122917         100000            18         2           3
# 4            144902         130000             3         2           3
#
#    ex_range
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              4340 non-null   int32
#  1   year              4340 non-null   int64
#  2   km_driven         4340 non-null   int64
#  3   fuel              4340 non-null   int32
#  4   seller_type       4340 non-null   int32
#  5   transmission      4340 non-null   int32
#  6   owner             4340 non-null   int32
#  7   Rating            4340 non-null   float64
#  8   ExShowroom Price  4340 non-null   int64
#  9   selling_price     4340 non-null   int64
#  10  company_name      4340 non-null   int32
#  11  km_range          4340 non-null   int32
#  12  year_range        4340 non-null   int32
#  13  ex_range          4340 non-null   int32
# dtypes: float64(1), int32(9), int64(4)
# memory usage: 322.2 KB

# %% [markdown]
# # Correlation: range(-1 to +1)

# %%
corr=data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f842e_row0_col0, #T_f842e_row1_col1, #T_f842e_row2_col2, #T_f842e_row3_col3, #T_f842e_row4_col4, #T_f842e_row5_col5, #T_f842e_row6_col6, #T_f842e_row7_col7, #T_f842e_row8_col8, #T_f842e_row9_col9, #T_f842e_row10_col10, #T_f842e_row11_col11, #T_f842e_row12_col12, #T_f842e_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f842e_row0_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_f842e_row0_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f842e_row0_col3, #T_f842e_row5_col0, #T_f842e_row12_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_f842e_row0_col4, #T_f842e_row1_col5, #T_f842e_row1_col11, #T_f842e_row4_col3, #T_f842e_row4_col8, #T_f842e_row5_col3, #T_f842e_row11_col6, #T_f842e_row12_col11 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f842e_row0_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_f842e_row0_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_f842e_row0_col7, #T_f842e_row8_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f842e_row0_col8, #T_f842e_row0_col9, #T_f842e_row7_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_f842e_row0_col10 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_f842e_row0_col11, #T_f842e_row2_col4, #T_f842e_row4_col10, #T_f842e_row6_col1, #T_f842e_row6_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_f842e_row0_col12 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f842e_row0_col13 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_f842e_row1_col0, #T_f842e_row6_col7, #T_f842e_row6_col13 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f842e_row1_col2, #T_f842e_row1_col6, #T_f842e_row1_col12, #T_f842e_row2_col3, #T_f842e_row2_col11, #T_f842e_row3_col0, #T_f842e_row3_col10, #T_f842e_row3_col13, #T_f842e_row5_col8, #T_f842e_row5_col9, #T_f842e_row9_col4, #T_f842e_row9_col5, #T_f842e_row9_col7, #T_f842e_row12_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f842e_row1_col3, #T_f842e_row7_col4, #T_f842e_row12_col10 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f842e_row1_col4, #T_f842e_row5_col7, #T_f842e_row10_col7, #T_f842e_row11_col7, #T_f842e_row11_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f842e_row1_col7, #T_f842e_row2_col7, #T_f842e_row4_col7, #T_f842e_row8_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_f842e_row1_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_f842e_row1_col9 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_f842e_row1_col10, #T_f842e_row2_col13 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f842e_row1_col13, #T_f842e_row7_col13, #T_f842e_row8_col6 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_f842e_row2_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f842e_row2_col1, #T_f842e_row12_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_f842e_row2_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_f842e_row2_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f842e_row2_col8, #T_f842e_row13_col6, #T_f842e_row13_col11 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_f842e_row2_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f842e_row2_col10 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_f842e_row2_col12 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_f842e_row3_col1, #T_f842e_row10_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_f842e_row3_col2, #T_f842e_row7_col0, #T_f842e_row13_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_f842e_row3_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f842e_row3_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f842e_row3_col6, #T_f842e_row11_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_f842e_row3_col7, #T_f842e_row8_col5, #T_f842e_row9_col10 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_f842e_row3_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f842e_row3_col9 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_f842e_row3_col11, #T_f842e_row10_col6 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f842e_row3_col12 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_f842e_row4_col0, #T_f842e_row4_col11, #T_f842e_row6_col9 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_f842e_row4_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f842e_row4_col2, #T_f842e_row5_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_f842e_row4_col5, #T_f842e_row7_col12 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_f842e_row4_col6, #T_f842e_row13_col12 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_f842e_row4_col9, #T_f842e_row9_col12 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_f842e_row4_col12 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f842e_row4_col13, #T_f842e_row11_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f842e_row5_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_f842e_row5_col4, #T_f842e_row10_col8, #T_f842e_row10_col9 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_f842e_row5_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f842e_row5_col10 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f842e_row5_col11 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f842e_row5_col12 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_f842e_row5_col13, #T_f842e_row8_col0, #T_f842e_row9_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_f842e_row6_col0, #T_f842e_row10_col13 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f842e_row6_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_f842e_row6_col3, #T_f842e_row6_col11, #T_f842e_row7_col3, #T_f842e_row10_col11 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f842e_row6_col4, #T_f842e_row7_col11 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_f842e_row6_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_f842e_row6_col10, #T_f842e_row13_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f842e_row6_col12 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_f842e_row7_col1, #T_f842e_row11_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_f842e_row7_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_f842e_row7_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_f842e_row7_col8 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_f842e_row7_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_f842e_row7_col10, #T_f842e_row12_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f842e_row8_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_f842e_row8_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_f842e_row8_col7, #T_f842e_row8_col10 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_f842e_row8_col9, #T_f842e_row9_col8, #T_f842e_row10_col0 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_f842e_row8_col11, #T_f842e_row9_col11 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f842e_row8_col12 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_f842e_row8_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_f842e_row9_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f842e_row9_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_f842e_row9_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f842e_row9_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f842e_row9_col13, #T_f842e_row10_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_f842e_row10_col1 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_f842e_row10_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f842e_row10_col5 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f842e_row10_col12 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_f842e_row11_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f842e_row11_col4, #T_f842e_row11_col13 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_f842e_row11_col5 {
#   background-color: #b1c

# %%
data=data.drop(['name','ExShowroom Price'],axis=1)
data.head(2)
# Out:
#    year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# 0  2010     120000     1            1             1      2     9.0
# 1  2012      50000     4            1             1      2     9.0
#
#    selling_price  company_name  km_range  year_range  ex_range
# 0         100000            25         0           3         0
# 1         100000            25         2           1         0

# %% [markdown]
# # Define X & Y

# %%
X=data.drop('selling_price',axis=1)
y=data.selling_price

# %%
X
# Out:
#       year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# 0     2010     120000     1            1             1      2    9.00
# 1     2012      50000     4            1             1      2    9.00
# 2     2011      70000     1            1             1      0   11.00
# 3     2010      80000     4            1             1      2    9.00
# 4     2010      80000     4            1             1      2   10.00
# ...    ...        ...   ...          ...           ...    ...     ...
# 4335  2019      30000     1            0             0      0   11.00
# 4336  2019      12999     1            0             0      0    9.71
# 4337  2019      30000     1            0             0      0   11.00
# 4338  2016      13000     4            0             0      0   14.09
# 4339  2017       6500     1            0             0      0    9.00
#
#       company_name  km_range  year_range  ex_range
# 0               25         0           3         0
# 1               25         2           1         0
# 2               25         2           1         0
# 3               18         2           3         0
# 4                3         2           3         0
# ...            ...       ...         ...       ...
# 4335             2         1           0         2
# 4336             2         1           0         2
# 4337             2         1           0         2
# 4338             1         1           0         2
# 4339            19         1           0         2
#
# [4340 rows x 11 columns]

# %%
X.head()
# Out:
#    year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# 0  2010     120000     1            1             1      2     9.0
# 1  2012      50000     4            1             1      2     9.0
# 2  2011      70000     1            1             1      0    11.0
# 3  2010      80000     4            1             1      2     9.0
# 4  2010      80000     4            1             1      2    10.0
#
#    company_name  km_range  year_range  ex_range
# 0            25         0           3         0
# 1            25         2           1         0
# 2            25         2           1         0
# 3            18         2           3         0
# 4             3         2           3         0

# %%
y.head()
# Out:
# 0    100000
# 1    100000
# 2    120000
# 3    100000
# 4    130000
# Name: selling_price, dtype: int64

# %% [markdown]
# # Data Scaling

# %%
round(X.describe(),2)
# Out:
#           year  km_driven     fuel  seller_type  transmission    owner  \
# count  4340.00    4340.00  4340.00      4340.00        4340.0  4340.00
# mean   2013.09   66215.78     2.47         0.79           0.9     0.82
# std       4.22   46644.10     1.51         0.46           0.3     1.23
# min    1992.00       1.00     0.00         0.00           0.0     0.00
# 25%    2011.00   35000.00     1.00         1.00           1.0     0.00
# 50%    2014.00   60000.00     1.00         1.00           1.0     0.00
# 75%    2016.00   90000.00     4.00         1.00           1.0     2.00
# max    2020.00  806599.00     4.00         2.00           1.0     4.00
#
#         Rating  company_name  km_range  year_range  ex_range
# count  4340.00       4340.00   4340.00     4340.00   4340.00
# mean     11.96         15.56      1.40        1.10      1.61
# std       1.91          6.81      0.76        1.06      1.34
# min       9.00          0.00      0.00        0.00      0.00
# 25%      10.02         10.00      1.00        0.00      0.00
# 50%      12.00         18.00      2.00        1.00      2.00
# 75%      13.76         18.00      2.00        1.00      3.00
# max      15.00         28.00      2.00        3.00      3.00

# %%
all_x=list(X.columns)
X[all_x]=X[all_x]/(X[all_x].max())
round(X.describe(),2)
# Out:
#           year  km_driven     fuel  seller_type  transmission    owner  \
# count  4340.00    4340.00  4340.00      4340.00        4340.0  4340.00
# mean      1.00       0.08     0.62         0.40           0.9     0.21
# std       0.00       0.06     0.38         0.23           0.3     0.31
# min       0.99       0.00     0.00         0.00           0.0     0.00
# 25%       1.00       0.04     0.25         0.50           1.0     0.00
# 50%       1.00       0.07     0.25         0.50           1.0     0.00
# 75%       1.00       0.11     1.00         0.50           1.0     0.50
# max       1.00       1.00     1.00         1.00           1.0     1.00
#
#         Rating  company_name  km_range  year_range  ex_range
# count  4340.00       4340.00   4340.00     4340.00   4340.00
# mean      0.80          0.56      0.70        0.37      0.54
# std       0.13          0.24      0.38        0.35      0.45
# min       0.60          0.00      0.00        0.00      0.00
# 25%       0.67          0.36      0.50        0.00      0.00
# 50%       0.80          0.64      1.00        0.33      0.67
# 75%       0.92          0.64      1.00        0.33      1.00
# max       1.00          1.00      1.00        1.00      1.00

# %%
X.head(5)
# Out:
#        year  km_driven  fuel  seller_type  transmission  owner    Rating  \
# 0  0.995050   0.148773  0.25          0.5           1.0    0.5  0.600000
# 1  0.996040   0.061989  1.00          0.5           1.0    0.5  0.600000
# 2  0.995545   0.086784  0.25          0.5           1.0    0.0  0.733333
# 3  0.995050   0.099182  1.00          0.5           1.0    0.5  0.600000
# 4  0.995050   0.099182  1.00          0.5           1.0    0.5  0.666667
#
#    company_name  km_range  year_range  ex_range
# 0      0.892857       0.0    1.000000       0.0
# 1      0.892857       1.0    0.333333       0.0
# 2      0.892857       1.0    0.333333       0.0
# 3      0.642857       1.0    1.000000       0.0
# 4      0.107143       1.0    1.000000       0.0

# %% [markdown]
# # Dividing Dataset Into Training And Testing Data

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=1234)

print(len(X_train))
print(len(X_test))
#print((X_train))
#print((X_test))
# Out:
# 3038
# 1302

# %%
print(X_test)
# Out:
#           year  km_driven  fuel  seller_type  transmission  owner    Rating  \
# 3866  0.997030   0.167369  0.25          0.5           0.0   1.00  0.666667
# 909   0.998515   0.018597  1.00          0.0           1.0   0.50  0.759333
# 1866  0.996040   0.037193  1.00          0.5           1.0   0.50  0.607333
# 1532  0.996040   0.193405  0.25          0.5           1.0   0.00  0.933333
# 1028  0.997030   0.079345  1.00          0.5           1.0   0.50  0.600000
# ...        ...        ...   ...          ...           ...    ...       ...
# 2595  0.993069   0.099182  1.00          0.5           0.0   0.25  0.800000
# 1775  0.989109   0.043392  0.75          0.5           1.0   0.50  0.600000
# 4019  0.998515   0.024795  1.00          0.0           0.0   0.50  1.000000
# 2762  0.998515   0.039673  0.25          0.5           1.0   0.50  0.864000
# 2890  0.998515   0.049591  0.25          0.5           1.0   0.00  0.866667
#
#       company_name  km_range  year_range  ex_range
# 3866      0.857143       0.0    0.333333  0.333333
# 909       0.178571       0.5    0.000000  0.000000
# 1866      0.357143       0.5    0.333333  1.000000
# 1532      0.642857       0.0    0.333333  1.000000
# 1028      0.642857       1.0    0.333333  0.000000
# ...            ...       ...         ...       ...
# 2595      0.357143       1.0    1.000000  1.000000
# 1775      0.642857       0.5    0.666667  1.000000
# 4019      0.964286       0.5    0.000000  0.666667
# 2762      0.821429       0.5    0.000000  1.000000
# 2890      0.607143       1.0    0.000000  1.000000
#
# [1302 rows x 11 columns]

# %%
print(len(y_train))
print(len(y_test))
# Out:
# 3038
# 1302

# %% [markdown]
# # Data Preprocessing Ends Here

# %% [markdown]
# # Regression

# %% [markdown]
# # Step 1: Polynomial Feature Creation

# %%
poly_reg=PolynomialFeatures(degree=2)
X_train_p=poly_reg.fit_transform(X_train)
X_test_p=poly_reg.fit_transform(X_test)

# %%
total_columns=len(X_train_p[0])
print(total_columns)
# Out:
# 78

# %% [markdown]
# # Method 1: Linear Regression

# %%
########## Define Model #################
model=LinearRegression()

########## Fit the train data ##############

model.fit(X_train, y_train)


########### Predict The values ##############
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([1297399.91739812,  499911.36079102,  344915.33997599, ...,
#        1307872.34000459,  728933.64981447,  730930.53872418])

# %%
y_test
# Out:
# 3866    1200000
# 909      210000
# 1866     280000
# 1532     250000
# 1028     290000
#          ...
# 2595     275000
# 1775      50000
# 4019     850000
# 2762     610000
# 2890     409999
# Name: selling_price, Length: 1302, dtype: int64

# %%
accuracy=r2_score(y_test,y_pred)*100

# %%
round(accuracy,2)
# Out:
# 47.45

# %% [markdown]
# # Method 1(a): Linear Regression With Polynomial Data

# %%
########## Define Model #################
model=LinearRegression()

########## Fit the train data ##############

model.fit(X_train_p, y_train)


########### Predict The values ##############
y_pred=model.predict(X_test_p)

accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))

importance=model.coef_
for i,j in enumerate(importance):
    print('Feature: %d, Score: %.1f'%(i,j))
# Out:
# 70.15
# Feature: 0, Score: 0.0
# Feature: 1, Score: -10285249060.7
# Feature: 2, Score: -5670268.6
# Feature: 3, Score: 49932560.7
# Feature: 4, Score: 60770175.1
# Feature: 5, Score: 11919900147373817856.0
# Feature: 6, Score: 20843066.1
# Feature: 7, Score: 45923968.8
# Feature: 8, Score: 36378112.3
# Feature: 9, Score: -24566264.8
# Feature: 10, Score: -92283966.4
# Feature: 11, Score: -38842744.3
# Feature: 12, Score: 5214350038.3
# Feature: 13, Score: -2328638.0
# Feature: 14, Score: -51345110.4
# Feature: 15, Score: -62020310.7
# Feature: 16, Score: -14419483.5
# Feature: 17, Score: -21016342.2
# Feature: 18, Score: -46897459.2
# Feature: 19, Score: -37047074.0
# Feature: 20, Score: 23758773.6
# Feature: 21, Score: 92281839.4
# Feature: 22, Score: 41719297.3
# Feature: 23, Score: 3375788.5
# Feature: 24, Score: 1038042.6
# Feature: 25, Score: 1779760.4
# Feature: 26, Score: 4363780.3
# Feature: 27, Score: 910675.5
# Feature: 28, Score: 261966.3
# Feature: 29, Score: 1017383.6
# Feature: 30, Score: 1705840.0
# Feature: 31, Score: -409385.1
# Feature: 32, Score: -207773.9
# Feature: 33, Score: -104512.0
# Feature: 34, Score: 110352.0
# Feature: 35, Score: 1162496.0
# Feature: 36, Score: 26112.0
# Feature: 37, Score: -12672.0
# Feature: 38, Score: -110080.0
# Feature: 39, Score: 273920.0
# Feature: 40, Score: -94720.0
# Feature: 41, Score: -154368.0
# Feature: 42, Score: 299648.0
# Feature: 43, Score: 130816.0
# Feature: 44, Score: 33344.0
# Feature: 45, Score: 289792.0
# Feature: 46, Score: 171072.0
# Feature: 47, Score: 277760.0
# Feature: 48, Score: -234112.0
# Feature: 49, Score: 72384.0
# Feature: 50, Score: -11919900147361597440.0
# Feature: 51, Score: 91904.0
# Feature: 52, Score: 340480.0
# Feature: 53, Score: 333312.0
# Feature: 54, Score: 249856.0
# Feature: 55, Score: 373248.0
# Feature: 56, Score: -200192.0
# Feature: 57, Score: -29440.0
# Feature: 58, Score: -103360.0
# Feature: 59, Score: -62080.0
# Feature: 60, Score: 72816.0
# Feature: 61, Score: -46080.0
# Feature: 62, Score: -38016.0
# Feature: 63, Score: 356608.0
# Feature: 64, Score: -415488.0
# Feature: 65, Score: 33280.0
# Feature: 66, Score: -87040.0
# Feature: 67, Score: -27584.0
# Feature: 68, Score: 416512.0
# Feature: 69, Score: 147968.0
# Feature: 70, Score: -168384.0
# Feature: 71, Score: -19968.0
# Feature: 72, Score: 36096.0
# Feature: 73, Score: 4160.0
# Feature: 74, Score: 14592.0
# Feature: 75, Score: 349696.0
# Feature: 76, Score: -2048.0
# Feature: 77, Score: -2223104.0

# %% [markdown]
# # Method 2: Ridge Regression

# %%
########## Define Model #################
model=Ridge()

########## Fit the train data ##############

model.fit(X_train_p, y_train)

########### Predict The values ##############

y_pred=model.predict(X_test_p)

########### Accuracy ####################
accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))


importance=model.coef_
for i,j in enumerate(importance):
    print('Feature: %d, Score: %.1f'%(i,j))
# Out:
# 68.21
# Feature: 0, Score: 0.0
# Feature: 1, Score: 107965.1
# Feature: 2, Score: -480350.7
# Feature: 3, Score: -424463.9
# Feature: 4, Score: -391530.4
# Feature: 5, Score: -644156.1
# Feature: 6, Score: -148499.9
# Feature: 7, Score: -83242.8
# Feature: 8, Score: -280250.5
# Feature: 9, Score: -44286.6
# Feature: 10, Score: -595394.1
# Feature: 11, Score: 1222295.7
# Feature: 12, Score: 214882.4
# Feature: 13, Score: -470159.3
# Feature: 14, Score: -371803.7
# Feature: 15, Score: -358370.1
# Feature: 16, Score: -562404.5
# Feature: 17, Score: -123042.9
# Feature: 18, Score: -150.0
# Feature: 19, Score: -230121.5
# Feature: 20, Score: 33850.7
# Feature: 21, Score: -538996.1
# Feature: 22, Score: 1304482.0
# Feature: 23, Score: -40187.3
# Feature: 24, Score: 339346.1
# Feature: 25, Score: 239737.7
# Feature: 26, Score: 983186.0
# Feature: 27, Score: 270975.9
# Feature: 28, Score: -243163.1
# Feature: 29, Score: 216959.6
# Feature: 30, Score: -59758.3
# Feature: 31, Score: -51925.9
# Feature: 32, Score: -315657.7
# Feature: 33, Score: -318874.8
# Feature: 34, Score: 17812.8
# Feature: 35, Score: 1023361.6
# Feature: 36, Score: 58566.8
# Feature: 37, Score: -70695.0
# Feature: 38, Score: -153374.6
# Feature: 39, Score: 234159.9
# Feature: 40, Score: 155546.1
# Feature: 41, Score: -154739.8
# Feature: 42, Score: 267905.3
# Feature: 43, Score: 121108.8
# Feature: 44, Score: -17066.6
# Feature: 45, Score: 70127.3
# Feature: 46, Score: 59010.0
# Feature: 47, Score: 279341.2
# Feature: 48, Score: 171028.4
# Feature: 49, Score: 62069.1
# Feature: 50, Score: -644156.1
# Feature: 51, Score: 217785.9
# Feature: 52, Score: 125327.3
# Feature: 53, Score: 399350.1
# Feature: 54, Score: 184908.7
# Feature: 55, Score: 613083.8
# Feature: 56, Score: -132624.7
# Feature: 57, Score: 7044.7
# Feature: 58, Score: -25110.5
# Feature: 59, Score: 19970.9
# Feature: 60, Score: 11384.0
# Feature: 61, Score: 31387.0
# Feature: 62, Score: -46531.8
# Feature: 63, Score: 62682.3
# Feature: 64, Score: -309904.1
# Feature: 65, Score: -26568.4
# Feature: 66, Score: 70408.3
# Feature: 67, Score: -1019.3
# Feature: 68, Score: 333872.8
# Feature: 69, Score: 86715.8
# Feature: 70, Score: 5758.5
# Feature: 71, Score: -1049.0
# Feature: 72, Score: -409929.2
# Feature: 73, Score: -66869.8
# Feature: 74, Score: 22348.5
# Feature: 75, Score: 207134.0
# Feature: 76, Score: -187954.4
# Feature: 77, Score: -2051217.2

# %% [markdown]
# # Method 3: Lasso Regression

# %%
########## Define Model #################
model=Lasso()

########## Fit the train data ##############

model.fit(X_train_p, y_train)


########### Predict The values ##############

y_pred=model.predict(X_test_p)

########### Accuracy ####################
accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))
# Out:
# 69.41

# %% [markdown]
# # Method 4: ElasticNet

# %%
########## Define Model #################
model=ElasticNet()

########## Fit the train data ##############

model.fit(X_train_p, y_train)


########### Predict The values ##############

y_pred=model.predict(X_test_p)

########### Accuracy ####################
accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))
# Out:
# 34.99

# %% [markdown]
# # Method 5:KNeighbour Regression

# %%
########## Define Model #################
model=KNeighborsRegressor()

########## Fit the train data ##############

model.fit(X_train_p, y_train)


########### Predict The values ##############

y_pred=model.predict(X_test_p)

########### Accuracy ####################
accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))
# Out:
# 75.76

# %% [markdown]
# # Method 6: Support Vector Regression

# %%
########## Define Model #################
model=SVR()

########## Fit the train data ##############

model.fit(X_train_p, y_train)


########### Predict The values ##############

y_pred=model.predict(X_test_p)

########### Accuracy ####################
accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))
# Out:
# -6.12

# %% [markdown]
# # Method 7: Random Forest Regression

# %%
########## Define Model #################
model=RandomForestRegressor()

########## Fit the train data ##############

model.fit(X_train_p, y_train)


########### Predict The values ##############

y_pred=model.predict(X_test_p)

########### Accuracy ####################
accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))
# Out:
# 84.46

# %% [markdown]
# # Method 8: Decision Tree Regression

# %%
########## Define Model #################
model=DecisionTreeRegressor()

########## Fit the train data ##############

model.fit(X_train_p, y_train)


########### Predict The values ##############

y_pred=model.predict(X_test_p)

########### Accuracy ####################
accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))
# Out:
# 73.81

# %% [markdown]
# # Method 9: Bagging Regression

# %%
########## Define Model #################
model=BaggingRegressor()

########## Fit the train data ##############

model.fit(X_train_p, y_train)


########### Predict The values ##############

y_pred=model.predict(X_test_p)

########### Accuracy ####################
accuracy=r2_score(y_test,y_pred)*100
print(round(accuracy,2))
# Out:
# 77.98

# %% [markdown]
# # Deployment Of Most Accurate Model

# %% [markdown]
# #Step 1: Save the model

# %%
################ Define The Most Accurate Model ############

model=RandomForestRegressor()
model.fit(X_train_p,y_train)

filename='Most_Accurate_Reg_Model.sav'
pickle.dump(model,open(file=filename,mode='wb'))

# %% [markdown]
# # Using Deployed Model

# %% [markdown]
# #Step 2: Use the saved model

# %%
################ Define The Most Accurate Model ############

model_load=pickle.load(open(file=filename,mode='rb'))

y_pred=model_load.predict(X_test_p[15:16])

############ Write A Data Preproceess ##############

print(y_pred)
# Out:
# [545479.99]

# %%
X_test.iloc[15:16]
# Out:
#           year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# 2736  0.998515   0.148773  0.25          0.5           1.0    0.0     0.6
#
#       company_name  km_range  year_range  ex_range
# 2736      0.607143       0.0         0.0       1.0

# %%
data.iloc[2736]
# Out:
# year               2017.0
# km_driven        120000.0
# fuel                  1.0
# seller_type           1.0
# transmission          1.0
# owner                 0.0
# Rating                9.0
# selling_price    628000.0
# company_name         17.0
# km_range              0.0
# year_range            0.0
# ex_range              3.0
# Name: 2736, dtype: float64

# %%
y_pred=model_load.predict(X_test_p[25:26])
print(y_pred)
# Out:
# [102999.99]

# %%
X_test.iloc[25:26]
# Out:
#           year  km_driven  fuel  seller_type  transmission  owner    Rating  \
# 1603  0.994059   0.148773   1.0          0.5           1.0    1.0  0.970667
#
#       company_name  km_range  year_range  ex_range
# 1603      0.642857       0.0         1.0       1.0

# %%
data.iloc[1603]
# Out:
# year               2008.00
# km_driven        120000.00
# fuel                  4.00
# seller_type           1.00
# transmission          1.00
# owner                 4.00
# Rating               14.56
# selling_price    110000.00
# company_name         18.00
# km_range              0.00
# year_range            3.00
# ex_range              3.00
# Name: 1603, dtype: float64

# %%
y_pred=model_load.predict(X_test_p[0:1])
print(y_pred)
# Out:
# [811189.99]

# %%
X_test.iloc[0:1]
# Out:
#          year  km_driven  fuel  seller_type  transmission  owner    Rating  \
# 3866  0.99703   0.167369  0.25          0.5           0.0    1.0  0.666667
#
#       company_name  km_range  year_range  ex_range
# 3866      0.857143       0.0    0.333333  0.333333

# %%
data.iloc[3866]
# Out:
# year                2014.0
# km_driven         135000.0
# fuel                   1.0
# seller_type            1.0
# transmission           0.0
# owner                  4.0
# Rating                10.0
# selling_price    1200000.0
# company_name          24.0
# km_range               0.0
# year_range             1.0
# ex_range               1.0
# Name: 3866, dtype: float64

# %%
y_pred=model_load.predict(X_test_p[7:8])
print(y_pred)
# Out:
# [606036.66666667]

# %%
X_test.iloc[7:8]
# Out:
#          year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# 3265  0.99802   0.099171  0.25          0.0           1.0    0.0     0.6
#
#       company_name  km_range  year_range  ex_range
# 3265      0.642857       1.0         0.0       1.0

# %%
data.iloc[3265]
# Out:
# year               2016.0
# km_driven         79991.0
# fuel                  1.0
# seller_type           0.0
# transmission          1.0
# owner                 0.0
# Rating                9.0
# selling_price    701000.0
# company_name         18.0
# km_range              2.0
# year_range            0.0
# ex_range              3.0
# Name: 3265, dtype: float64

# %%
table = data.groupby(by='company_name').agg('count')
print(table)
# Out:
#               year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# company_name
# 0                4          4     4            4             4      4       4
# 1               60         60    60           60            60     60      60
# 2               39         39    39           39            39     39      39
# 3              188        188   188          188           188    188     188
# 4                1          1     1            1             1      1       1
# 5               37         37    37           37            37     37      37
# 6               37         37    37           37            37     37      37
# 7                1          1     1            1             1      1       1
# 8              238        238   238          238           238    238     238
# 9              252        252   252          252           252    252     252
# 10             821        821   821          821           821    821     821
# 11               1          1     1            1             1      1       1
# 12               6          6     6            6             6      6       6
# 13               3          3     3            3             3      3       3
# 14               1          1     1            1             1      1       1
# 15               5          5     5            5             5      5       5
# 16               2          2     2            2             2      2       2
# 17             365        365   365          365           365    365     365
# 18            1280       1280  1280         1280          1280   1280    1280
# 19              35         35    35           35            35     35      35
# 20               6          6     6            6             6      6       6
# 21              64         64    64           64            64     64      64
# 22               2          2     2            2             2      2       2
# 23             146        146   146          146           146    146     146
# 24              68         68    68           68            68     68      68
# 25             361        361   361          361           361    361     361
# 26             206        206   206          206           206    206     206
# 27             107        107   107          107           107    107     107
# 28               4          4     4            4             4      4       4
#
#               selling_price  km_range  year_range  ex_range
# company_name
# 0                         4         4           4         4
# 1                        60        60          60        60
# 2                        39        39          39        39
# 3                       188       188         188       188
# 4                         1         1           1         1
# 5                        37        37          37        37
# 6                        37        37          37        37
# 7                         1         1           1         1
# 8                       238       238         238       238
# 9                       252       252         252       252
# 10                      821       821         821       821
# 11                        1         1           1         1
# 12                        6         6           6         6
# 13                        3         3           3         3
# 14                        1         1           1         1
# 15                        5         5           5         5
# 16                        2         2           2         2
# 17                      365       365         365       365
# 18                     1280      1280        1280      1280
# 19                       35        35          35        35
# 20                        6         6           6         6
# 21                       64        64          64        64
# 22                        2         2           2         2
# 23                      146       146         146       146
# 24                       68        68          68        68
# 25                      361       361         361       361
# 26                      206       206         206       206
# 27                      107       107         107       107
# 28                        4         4           4         4

# %%
table=data.groupby(by='company_name').agg('count')
x=data.company_name.unique()
x=list(x)
x.sort()
y=table['year']
plt.xlabel('Company Name', fontsize=10)
plt.ylabel('Count', fontsize=12)
plt.bar(x,y)
plt.savefig('bar1.png',bbox_inches="tight",pad_inches=2,transparent=True)
plt.show()

# %%
table=data.groupby(by='year').agg('count')
print(table)
x=data.year.unique()
x=list(x)
x.sort()
y=table['fuel']
plt.xlabel('Year', fontsize=10)
plt.ylabel('Count', fontsize=12)
plt.bar(x,y)
#for i in range(len(x)):
    # plt.text(i, y[i], "Hello", ha="center" , va="bottom")
plt.savefig('bar2.png',bbox_inches="tight",pad_inches=2,transparent=True)
plt.show()
# Out:
#       km_driven  fuel  seller_type  transmission  owner  Rating  \
# year
# 1992          1     1            1             1      1       1
# 1995          1     1            1             1      1       1
# 1996          2     2            2             2      2       2
# 1997          3     3            3             3      3       3
# 1998         12    12           12            12     12      12
# 1999         10    10           10            10     10      10
# 2000         12    12           12            12     12      12
# 2001         20    20           20            20     20      20
# 2002         21    21           21            21     21      21
# 2003         23    23           23            23     23      23
# 2004         42    42           42            42     42      42
# 2005         85    85           85            85     85      85
# 2006        110   110          110           110    110     110
# 2007        134   134          134           134    134     134
# 2008        145   145          145           145    145     145
# 2009        193   193          193           193    193     193
# 2010        234   234          234           234    234     234
# 2011        271   271          271           271    271     271
# 2012        415   415          415           415    415     415
# 2013        386   386          386           386    386     386
# 2014        367   367          367           367    367     367
# 2015        421   421          421           421    421     421
# 2016        357   357          357           357    357     357
# 2017        466   466          466           466    466     466
# 2018        366   366          366           366    366     366
# 2019        195   195          195           195    195     195
# 2020         48    48           48            48     48      48
#
#       selling_price  company_name  km_range  year_range  ex_range
# year
# 1992              1             1         1           1         1
# 1995              1             1         1           1         1
# 1996              2             2         2           2         2
# 1997              3             3         3           3         3
# 1998             12            12        12          12        12
# 1999             10            10        10          10        10
# 2000             12            12        12          12        12
# 2001             20            20        20          20        20
# 2002             21            21        21          21        21
# 2003             23            23        23          23        23
# 2004             42            42        42          42        42
# 2005             85            85        85          85        85
# 2006            110           110       110         110       110
# 2007            134           134       134         134       134
# 2008            145           145       145         145       145
# 2009            193           193       193         193       193
# 2010            234           234       234         234       234
# 2011            271           271       271         271       271
# 2012            415           415       415         415       415
# 2013            386           386       386         386       386
# 2014            367           367       367         367       367
# 2015            421           421       421         421       421
# 2016            357           357       357         357       357
# 2017            466           466       466         466       466
# 2018            366           366       366         366       366
# 2019            195           195       195         195       195
# 2020             48            48        48          48        48

# %%
y=data['fuel']
y
x=data.fuel.unique();
x
# Out:
# array([1, 4, 0, 3, 2])

# %%
table=data.groupby(by='fuel').agg('count')
y=table['km_driven']
print(y)
x=list(x)
x.sort()
print(x)
plt.pie(y,labels=x,radius=3,autopct='%0.02f%%', shadow=True, explode=[.05,.2,.05,.5,.05])
plt.savefig('pie1.png',bbox_inches="tight",pad_inches=2,transparent=True)
plt.show()
# Out:
# fuel
# 0      40
# 1    2155
# 2       1
# 3      23
# 4    2121
# Name: km_driven, dtype: int64
# [0, 1, 2, 3, 4]
